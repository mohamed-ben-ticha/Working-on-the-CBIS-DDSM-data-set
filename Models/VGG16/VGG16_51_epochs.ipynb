# %% [markdown]
# # Importing The Necessary Dependencies

# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import tensorflow as tf 
from PIL import Image
import glob
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras import models
from PIL import Image

# %% [markdown]
# # Loading and Splitting The Data

# %%
images = glob.glob("DATA++\\Mass\\*_FULL_*.png")
mask = glob.glob("DATA++\\Mass\\*_MASK_*.png")

# %%
print(images[:5])
print('-------------------')
print(mask[:5])
# Out:
# ['DATA++\\Mass\\Mass-Test_P_00016_LEFT_CC_FULL_PRE.png', 'DATA++\\Mass\\Mass-Test_P_00016_LEFT_MLO_FULL_PRE.png', 'DATA++\\Mass\\Mass-Test_P_00017_LEFT_CC_FULL_PRE.png', 'DATA++\\Mass\\Mass-Test_P_00017_LEFT_MLO_FULL_PRE.png', 'DATA++\\Mass\\Mass-Test_P_00032_RIGHT_CC_FULL_PRE.png']
# -------------------
# ['DATA++\\Mass\\Mass-Test_P_00016_LEFT_CC_MASK_1___PRE.png', 'DATA++\\Mass\\Mass-Test_P_00016_LEFT_MLO_MASK_1___PRE.png', 'DATA++\\Mass\\Mass-Test_P_00017_LEFT_CC_MASK_1___PRE.png', 'DATA++\\Mass\\Mass-Test_P_00017_LEFT_MLO_MASK_1___PRE.png', 'DATA++\\Mass\\Mass-Test_P_00032_RIGHT_CC_MASK_1___PRE.png']

# %%
data = pd.DataFrame({'images':images,'masks':mask})
data.head(9)
# Out:
#                                               images
# 0  DATA++\Mass\Mass-Test_P_00016_LEFT_CC_FULL_PRE...  \
# 1  DATA++\Mass\Mass-Test_P_00016_LEFT_MLO_FULL_PR...
# 2  DATA++\Mass\Mass-Test_P_00017_LEFT_CC_FULL_PRE...
# 3  DATA++\Mass\Mass-Test_P_00017_LEFT_MLO_FULL_PR...
# 4  DATA++\Mass\Mass-Test_P_00032_RIGHT_CC_FULL_PR...
# 5  DATA++\Mass\Mass-Test_P_00032_RIGHT_MLO_FULL_P...
# 6  DATA++\Mass\Mass-Test_P_00037_RIGHT_CC_FULL_PR...
# 7  DATA++\Mass\Mass-Test_P_00037_RIGHT_MLO_FULL_P...
# 8  DATA++\Mass\Mass-Test_P_00056_LEFT_MLO_FULL_PR...
#
#                                                masks
# 0  DATA++\Mass\Mass-Test_P_00016_LEFT_CC_MASK_1__...
# 1  DATA++\Mass\Mass-Test_P_00016_LEFT_MLO_MASK_1_...
# 2  DATA++\Mass\Mass-Test_P_00017_LEFT_CC_MASK_1__...
# 3  DATA++\Mass\Mass-Test_P_00017_LEFT_MLO_MASK_1_...
# 4  DATA++\Mass\Mass-Test_P_00032_RIGHT_CC_MASK_1_...
# 5  DATA++\Mass\Mass-Test_P_00032_RIGHT_MLO_MASK_1...
# 6  DATA++\Mass\Mass-Test_P_00037_RIGHT_CC_MASK_1_...
# 7  DATA++\Mass\Mass-Test_P_00037_RIGHT_MLO_MASK_1...
# 8  DATA++\Mass\Mass-Test_P_00056_LEFT_MLO_MASK_1_...

# %%
data.shape
# Out:
# (1592, 2)

# %%
import cv2 
N=18
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
img=cv2.imread(data.images.iloc[N])
plt.imshow(img)
plt.subplot(1,3,2)
msk=cv2.imread(data.masks.iloc[N])
plt.imshow(msk)
plt.subplot(1,3,3)
plt.imshow(img)
plt.imshow(msk,alpha=0.5)

# %%
data_train,data_test=train_test_split(data,test_size=0.1)

data_train,data_val=train_test_split(data_train,test_size=0.2)

# %%
datagen = ImageDataGenerator(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest',
                            rescale=1./255)

# %%
image_train=datagen.flow_from_dataframe(data_train,  
                                    target_size=(256,256), 
                                    color_mode='rgb',
                                    shuffle=True,
                                    seed=123,
                                    x_col ="images", 
                                    batch_size=8,
                                    class_mode=None
                                    
)
mask_train=datagen.flow_from_dataframe(data_train, 
                                    target_size=(256,256), 
                                    color_mode='grayscale',
                                    shuffle=True,
                                    seed=123,
                                    x_col ="masks", 
                                    batch_size=8,
                                    class_mode=None
)
# Out:
# Found 1145 validated image filenames.
# Found 1145 validated image filenames.

# %%
image_validation=datagen.flow_from_dataframe(data_val,  
                                    target_size=(256,256), 
                                    color_mode='rgb',
                                    shuffle=True,
                                    seed=123,
                                    x_col ="images", 
                                    batch_size=8,
                                    class_mode=None
)

mask_validation=datagen.flow_from_dataframe(data_val, 
                                    target_size=(256,256), 
                                    color_mode='grayscale',
                                    shuffle=True,
                                    seed=123,
                                    x_col ="masks", 
                                    batch_size=8,
                                    class_mode=None
)
# Out:
# Found 287 validated image filenames.
# Found 287 validated image filenames.

# %%
train_gen=zip(image_train,mask_train)
valid_gen=zip(image_validation,mask_validation)

# %% [markdown]
# # Building The Model

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def buildEncoder(input_shape = (256,256,3)):
    
    try:
            VGG16_ = keras.applications.VGG16(
                include_top=False,
                weights="imagenet",
                input_shape=input_shape,
            )

            # Get list of layer names for skip connections later
            layer_names = [layer.name for layer in VGG16_.layers]

            # Get layer outputs
            all_layer_outputs = [
                VGG16_.get_layer(layer_name).output for layer_name in layer_names
            ]

            # Create encoder model
            encoder_model = keras.Model(inputs=VGG16_.input, outputs=all_layer_outputs)

            # Freeze layers
            encoder_model.trainable = False

    except Exception as e:
            print((f"Unable to buildEncoder!\n{e}"))

    return encoder_model

# %%
 def buildUnet(input_shape=(256,256,3), dropout_training=True):
        
        try:
            # =============
            #  Input layer
            # =============

            unet_input = keras.Input(
                shape=input_shape, name="unet_input_layer"
            )

            x = unet_input

            # =========
            #  Encoder
            # =========

            encoder_model = buildEncoder(input_shape)
            all_encoder_layer_outputs = encoder_model(x)

            # Get final encoder output (this will be the input for the decoder)
            encoded_img = all_encoder_layer_outputs[-1]

            # Get outputs to be used for skip connections
            # (I know the specific layers to be used for skip connections)
            skip_outputs = [all_encoder_layer_outputs[i] for i in [2, 5, 9, 13, 17]]

            # =========
            #  Decoder
            # =========

            decoder_filters = int(encoded_img.shape[-1])

            # ------------------------------------------
            # Block 5: 7x7 -> 14x14
            #  - `encoded_img` as initial input for decoder
            x = keras.layers.Conv2DTranspose(
                name="block5_up_convT",
                filters=decoder_filters,
                kernel_size=3,
                strides=2,
                padding="same",
                activation="relu",
            )(encoded_img)

            x = keras.layers.Concatenate(name="block5_up_concat", axis=-1)(
                [x, skip_outputs[4]]
            )

            x = keras.layers.Dropout(
                name="block5_up_dropout", rate=0.5, seed=123
            )(x, training=dropout_training)

            x = keras.layers.Conv2D(
                name="block5_up_conv3",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block5_up_conv2",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block5_up_conv1",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)

            # ------------------------------------------
            # Block 4: 14x14 -> 28x28
            x = keras.layers.Conv2DTranspose(
                name="block4_up_convT",
                filters=decoder_filters,
                kernel_size=3,
                strides=2,
                padding="same",
                activation="relu",
            )(x)

            x = keras.layers.Concatenate(name="block4_up_concat", axis=-1)(
                [x, skip_outputs[3]]
            )

            x = keras.layers.Dropout(
                name="block4_up_dropout", rate=0.5, seed=123
            )(x, training=dropout_training)

            x = keras.layers.Conv2D(
                name="block4_up_conv3",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block4_up_conv2",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block4_up_conv1",
                filters=decoder_filters,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)

            # ------------------------------------------
            # Block 3: 28x28 -> 56x56
            x = keras.layers.Conv2DTranspose(
                name="block3_up_convT",
                filters=int(decoder_filters / 2),
                kernel_size=3,
                strides=2,
                padding="same",
                activation="relu",
            )(x)

            x = keras.layers.Concatenate(name="block3_up_concat", axis=-1)(
                [x, skip_outputs[2]]
            )

            x = keras.layers.Dropout(
                name="block3_up_dropout", rate=0.5, seed=123
            )(x, training=dropout_training)

            x = keras.layers.Conv2D(
                name="block3_up_conv3",
                filters=int(decoder_filters / 2),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block3_up_conv2",
                filters=int(decoder_filters / 2),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block3_up_conv1",
                filters=int(decoder_filters / 2),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)

            # ------------------------------------------
            # Block 2: 56x56 -> 112x112
            x = keras.layers.Conv2DTranspose(
                name="block2_up_convT",
                filters=int(decoder_filters / 4),
                kernel_size=3,
                strides=2,
                padding="same",
                activation="relu",
            )(x)

            x = keras.layers.Concatenate(name="block2_up_concat", axis=-1)(
                [x, skip_outputs[1]]
            )

            x = keras.layers.Dropout(
                name="block2_up_dropout", rate=0.5, seed=123
            )(x, training=dropout_training)

            x = keras.layers.Conv2D(
                name="block2_up_conv2",
                filters=int(decoder_filters / 4),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            x = keras.layers.Conv2D(
                name="block2_up_conv1",
                filters=int(decoder_filters / 4),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)

            # ------------------------------------------
            # Block 1: 112x112 -> 224x224
            x = keras.layers.Conv2DTranspose(
                name="block1_up_convT",
                filters=int(decoder_filters / 8),
                kernel_size=3,
                strides=2,
                padding="same",
                activation="relu",
            )(x)

            x = keras.layers.Concatenate(name="block1_up_concat", axis=-1)(
                [x, skip_outputs[0]]
            )

            x = keras.layers.Dropout(
                name="block1_up_dropout", rate=0.5, seed=123
            )(x, training=dropout_training)

            x = keras.layers.Conv2D(
                name="block1_up_conv2",
                filters=int(decoder_filters / 8),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)
            decoded_img = keras.layers.Conv2D(
                name="block1_up_conv1",
                filters=int(decoder_filters / 8),
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="relu",
            )(x)

            # ------------------------------------------
            # Final conv layer
            final_img = keras.layers.Conv2D(
                name="final_up_conv",
                filters=1,
                kernel_size=3,
                strides=(1, 1),
                padding="same",
                activation="sigmoid",
            )(decoded_img)

            # ======
            #  Unet
            # ======

            unet = keras.Model(inputs=unet_input, outputs=final_img, name="Unet_VGG16")
            
            return unet
        
        except Exception as e:
            print((f"Unable to buildUnet!\n{e}"))

# %%
smooth=1
def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    return dice_coef_loss(y_true, y_pred) + bce(y_true, y_pred)

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='dice_coef', patience=50)
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='vgg16_checkpoint_256.h5', monitor='dice_coef', save_best_only=True)
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_dice_coef', factor=0.5, patience=4)

# %%
model = buildUnet(input_shape=(256, 256, 3))

# %%
model.summary()
# Out:
# Model: "Unet_VGG16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  unet_input_layer (InputLayer)  [(None, 256, 256, 3  0           []
#                                 )]
#
#  model (Functional)             [(None, 256, 256, 3  14714688    ['unet_input_layer[0][0]']
#                                 ),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 256, 256, 6
#                                 4),
#                                  (None, 128, 128, 6
#                                 4),
#                                  (None, 128, 128, 1
#                                 28),
#                                  (None, 128, 128, 1
#                                 28),
#                                  (None, 64, 64, 128
#                                 ),
#                                  (None, 64, 64, 256
#                                 ),
#                                  (None, 64, 64, 256
#                                 ),
#                                  (None, 64, 64, 256
#                                 ),
#                                  (None, 32, 32, 256
#                                 ),
#                                  (None, 32, 32, 512
#                                 ),
#                                  (None, 32, 32, 512
#                                 ),
#                                  (None, 32, 32, 512
#                                 ),
#                                  (None, 16, 16, 512
#                                 ),
#                                  (None, 16, 16, 512
#                                 ),
#                                  (None, 16, 16, 512
#                                 ),
#                                  (None, 16, 16, 512
#                                 ),
#                                  (None, 8, 8, 512)]
#
#  block5_up_convT (Conv2DTranspo  (None, 16, 16, 512)  2359808    ['model[0][18]']
#  se)
#
#  block5_up_concat (Concatenate)  (None, 16, 16, 1024  0          ['block5_up_convT[0][0]',
#                                 )                                 'model[0][17]']
#
#  block5_up_dropout (Dropout)    (None, 16, 16, 1024  0           ['block5_up_concat[0][0]']
#                                 )
#
#  block5_up_conv3 (Conv2D)       (None, 16, 16, 512)  4719104     ['block5_up_dropout[0][0]']
#
#  block5_up_conv2 (Conv2D)       (None, 16, 16, 512)  2359808     ['block5_up_conv3[0][0]']
#
#  block5_up_conv1 (Conv2D)       (None, 16, 16, 512)  2359808     ['block5_up_conv2[0][0]']
#
#  block4_up_convT (Conv2DTranspo  (None, 32, 32, 512)  2359808    ['block5_up_conv1[0][0]']
#  se)
#
#  block4_up_concat (Concatenate)  (None, 32, 32, 1024  0          ['block4_up_convT[0][0]',
#                                 )                                 'model[0][13]']
#
#  block4_up_dropout (Dropout)    (None, 32, 32, 1024  0           ['block4_up_concat[0][0]']
#                                 )
#
#  block4_up_conv3 (Conv2D)       (None, 32, 32, 512)  4719104     ['block4_up_dropout[0][0]']
#
#  block4_up_conv2 (Conv2D)       (None, 32, 32, 512)  2359808     ['block4_up_conv3[0][0]']
#
#  block4_up_conv1 (Conv2D)       (None, 32, 32, 512)  2359808     ['block4_up_conv2[0][0]']
#
#  block3_up_convT (Conv2DTranspo  (None, 64, 64, 256)  1179904    ['block4_up_conv1[0][0]']
#  se)
#
#  block3_up_concat (Concatenate)  (None, 64, 64, 512)  0          ['block3_up_convT[0][0]',
#                                                                   'model[0][9]']
#
#  block3_up_dropout (Dropout)    (None, 64, 64, 512)  0           ['block3_up_concat[0][0]']
#
#  block3_up_conv3 (Conv2D)       (None, 64, 64, 256)  1179904     ['block3_up_dropout[0][0]']
#
#  block3_up_conv2 (Conv2D)       (None, 64, 64, 256)  590080      ['block3_up_conv3[0][0]']
#
#  block3_up_conv1 (Conv2D)       (None, 64, 64, 256)  590080      ['block3_up_conv2[0][0]']
#
#  block2_up_convT (Conv2DTranspo  (None, 128, 128, 12  295040     ['block3_up_conv1[0][0]']
#  se)                            8)
#
#  block2_up_concat (Concatenate)  (None, 128, 128, 25  0          ['block2_up_convT[0][0]',
#                                 6)                                'model[0][5]']
#
#  block2_up_dropout (Dropout)    (None, 128, 128, 25  0           ['block2_up_concat[0][0]']
#                                 6)
#
#  block2_up_conv2 (Conv2D)       (None, 128, 128, 12  295040      ['block2_up_dropout[0][0]']
#                                 8)
#
#  block2_up_conv1 (Conv2D)       (None, 128, 128, 12  147584      ['block2_up_conv2[0][0]']
#                                 8)
#
#  block1_up_convT (Conv2DTranspo  (None, 256, 256, 64  73792      ['block2_up_conv1[0][0]']
#  se)                            )
#
#  block1_up_concat (Concatenate)  (None, 256, 256, 12  0          ['block1_up_convT[0][0]',
#                                 8)                                'model[0][2]']
#
#  block1_up_dropout (Dropout)    (None, 256, 256, 12  0           ['block1_up_concat[0][0]']
#                                 8)
#
#  block1_up_conv2 (Conv2D)       (None, 256, 256, 64  73792       ['block1_up_dropout[0][0]']
#                                 )
#
#  block1_up_conv1 (Conv2D)       (None, 256, 256, 64  36928       ['block1_up_conv2[0][0]']
#                                 )
#
#  final_up_conv (Conv2D)         (None, 256, 256, 1)  577         ['block1_up_conv1[0][0]']
#
# ==================================================================================================
# Total params: 42,774,465
# Trainable params: 28,059,777
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=bce_dice_loss,
    metrics=[dice_coef,'accuracy'])

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=60,
    validation_steps=len(data_val) /8,
    steps_per_epoch=len(data_train) /8,
    callbacks=[early_stopping_callback,checkpoint_callback,reduce_lr_callback]
)
# Out:
# Epoch 1/60
# C:\Users\b3nni\miniconda3\envs\tf\lib\site-packages\keras\backend.py:5673: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 143/143 [==============================] - 357s 2s/step - loss: 0.8076 - dice_coef: 0.2412 - accuracy: 0.9912 - val_loss: 0.5900 - val_dice_coef: 0.4348 - val_accuracy: 0.9955 - lr: 0.0010
# Epoch 2/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.6427 - dice_coef: 0.3933 - accuracy: 0.9946 - val_loss: 0.7537 - val_dice_coef: 0.2808 - val_accuracy: 0.9962 - lr: 0.0010
# Epoch 3/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.6417 - dice_coef: 0.3924 - accuracy: 0.9949 - val_loss: 0.6097 - val_dice_coef: 0.4189 - val_accuracy: 0.9951 - lr: 0.0010
# Epoch 4/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.6202 - dice_coef: 0.4110 - accuracy: 0.9949 - val_loss: 0.5430 - val_dice_coef: 0.4775 - val_accuracy: 0.9963 - lr: 0.0010
# Epoch 5/60
# 143/143 [==============================] - 320s 2s/step - loss: 0.6401 - dice_coef: 0.3935 - accuracy: 0.9946 - val_loss: 0.5770 - val_dice_coef: 0.4434 - val_accuracy: 0.9953 - lr: 0.0010
# Epoch 6/60
# 143/143 [==============================] - 316s 2s/step - loss: 0.6025 - dice_coef: 0.4303 - accuracy: 0.9951 - val_loss: 0.6121 - val_dice_coef: 0.4193 - val_accuracy: 0.9947 - lr: 0.0010
# Epoch 7/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5615 - dice_coef: 0.4641 - accuracy: 0.9955 - val_loss: 0.6222 - val_dice_coef: 0.4050 - val_accuracy: 0.9941 - lr: 5.0000e-04
# Epoch 8/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5672 - dice_coef: 0.4600 - accuracy: 0.9952 - val_loss: 0.5913 - val_dice_coef: 0.4317 - val_accuracy: 0.9954 - lr: 5.0000e-04
# Epoch 9/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5734 - dice_coef: 0.4541 - accuracy: 0.9953 - val_loss: 0.5825 - val_dice_coef: 0.4394 - val_accuracy: 0.9957 - lr: 5.0000e-04
# Epoch 10/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5744 - dice_coef: 0.4494 - accuracy: 0.9953 - val_loss: 0.5637 - val_dice_coef: 0.4642 - val_accuracy: 0.9956 - lr: 5.0000e-04
# Epoch 11/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5619 - dice_coef: 0.4630 - accuracy: 0.9956 - val_loss: 0.5699 - val_dice_coef: 0.4522 - val_accuracy: 0.9959 - lr: 2.5000e-04
# Epoch 12/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5582 - dice_coef: 0.4659 - accuracy: 0.9955 - val_loss: 0.6005 - val_dice_coef: 0.4225 - val_accuracy: 0.9955 - lr: 2.5000e-04
# Epoch 13/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5367 - dice_coef: 0.4841 - accuracy: 0.9955 - val_loss: 0.5501 - val_dice_coef: 0.4729 - val_accuracy: 0.9957 - lr: 2.5000e-04
# Epoch 14/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5370 - dice_coef: 0.4838 - accuracy: 0.9958 - val_loss: 0.5558 - val_dice_coef: 0.4700 - val_accuracy: 0.9962 - lr: 2.5000e-04
# Epoch 15/60
# 143/143 [==============================] - 329s 2s/step - loss: 0.5313 - dice_coef: 0.4940 - accuracy: 0.9958 - val_loss: 0.5272 - val_dice_coef: 0.4938 - val_accuracy: 0.9962 - lr: 1.2500e-04
# Epoch 16/60
# 143/143 [==============================] - 324s 2s/step - loss: 0.5237 - dice_coef: 0.4962 - accuracy: 0.9958 - val_loss: 0.5797 - val_dice_coef: 0.4441 - val_accuracy: 0.9956 - lr: 1.2500e-04
# Epoch 17/60
# 143/143 [==============================] - 324s 2s/step - loss: 0.5282 - dice_coef: 0.4956 - accuracy: 0.9958 - val_loss: 0.5578 - val_dice_coef: 0.4655 - val_accuracy: 0.9958 - lr: 1.2500e-04
# Epoch 18/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5245 - dice_coef: 0.5000 - accuracy: 0.9958 - val_loss: 0.5875 - val_dice_coef: 0.4370 - val_accuracy: 0.9957 - lr: 1.2500e-04
# Epoch 19/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5292 - dice_coef: 0.4951 - accuracy: 0.9958 - val_loss: 0.5090 - val_dice_coef: 0.5120 - val_accuracy: 0.9961 - lr: 6.2500e-05
# Epoch 20/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5418 - dice_coef: 0.4842 - accuracy: 0.9957 - val_loss: 0.5432 - val_dice_coef: 0.4780 - val_accuracy: 0.9958 - lr: 6.2500e-05
# Epoch 21/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5247 - dice_coef: 0.4999 - accuracy: 0.9959 - val_loss: 0.5469 - val_dice_coef: 0.4756 - val_accuracy: 0.9959 - lr: 6.2500e-05
# Epoch 22/60
# 143/143 [==============================] - 316s 2s/step - loss: 0.5259 - dice_coef: 0.4986 - accuracy: 0.9958 - val_loss: 0.5585 - val_dice_coef: 0.4643 - val_accuracy: 0.9961 - lr: 6.2500e-05
# Epoch 23/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5255 - dice_coef: 0.4945 - accuracy: 0.9958 - val_loss: 0.5482 - val_dice_coef: 0.4761 - val_accuracy: 0.9957 - lr: 3.1250e-05
# Epoch 24/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5225 - dice_coef: 0.4997 - accuracy: 0.9957 - val_loss: 0.5412 - val_dice_coef: 0.4813 - val_accuracy: 0.9959 - lr: 3.1250e-05
# Epoch 25/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5275 - dice_coef: 0.4959 - accuracy: 0.9958 - val_loss: 0.5531 - val_dice_coef: 0.4690 - val_accuracy: 0.9959 - lr: 3.1250e-05
# Epoch 26/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5200 - dice_coef: 0.4997 - accuracy: 0.9959 - val_loss: 0.4957 - val_dice_coef: 0.5249 - val_accuracy: 0.9961 - lr: 3.1250e-05
# Epoch 27/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5191 - dice_coef: 0.5041 - accuracy: 0.9959 - val_loss: 0.5660 - val_dice_coef: 0.4547 - val_accuracy: 0.9961 - lr: 1.5625e-05
# Epoch 28/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5085 - dice_coef: 0.5113 - accuracy: 0.9959 - val_loss: 0.5498 - val_dice_coef: 0.4715 - val_accuracy: 0.9960 - lr: 1.5625e-05
# Epoch 29/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5125 - dice_coef: 0.5065 - accuracy: 0.9958 - val_loss: 0.5386 - val_dice_coef: 0.4842 - val_accuracy: 0.9958 - lr: 1.5625e-05
# Epoch 30/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5164 - dice_coef: 0.5081 - accuracy: 0.9959 - val_loss: 0.5297 - val_dice_coef: 0.4889 - val_accuracy: 0.9963 - lr: 1.5625e-05
# Epoch 31/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5272 - dice_coef: 0.4957 - accuracy: 0.9958 - val_loss: 0.5168 - val_dice_coef: 0.5043 - val_accuracy: 0.9960 - lr: 7.8125e-06
# Epoch 32/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5155 - dice_coef: 0.5072 - accuracy: 0.9959 - val_loss: 0.5789 - val_dice_coef: 0.4445 - val_accuracy: 0.9958 - lr: 7.8125e-06
# Epoch 33/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5130 - dice_coef: 0.5112 - accuracy: 0.9959 - val_loss: 0.5423 - val_dice_coef: 0.4796 - val_accuracy: 0.9961 - lr: 7.8125e-06
# Epoch 34/60
# 143/143 [==============================] - 321s 2s/step - loss: 0.5159 - dice_coef: 0.5030 - accuracy: 0.9959 - val_loss: 0.5183 - val_dice_coef: 0.5024 - val_accuracy: 0.9961 - lr: 7.8125e-06
# Epoch 35/60
# 143/143 [==============================] - 321s 2s/step - loss: 0.5286 - dice_coef: 0.4910 - accuracy: 0.9958 - val_loss: 0.5301 - val_dice_coef: 0.4926 - val_accuracy: 0.9958 - lr: 3.9063e-06
# Epoch 36/60
# 143/143 [==============================] - 323s 2s/step - loss: 0.5225 - dice_coef: 0.5015 - accuracy: 0.9958 - val_loss: 0.5564 - val_dice_coef: 0.4656 - val_accuracy: 0.9957 - lr: 3.9063e-06
# Epoch 37/60
# 143/143 [==============================] - 324s 2s/step - loss: 0.5199 - dice_coef: 0.4991 - accuracy: 0.9959 - val_loss: 0.5573 - val_dice_coef: 0.4650 - val_accuracy: 0.9958 - lr: 3.9063e-06
# Epoch 38/60
# 143/143 [==============================] - 320s 2s/step - loss: 0.5153 - dice_coef: 0.5047 - accuracy: 0.9958 - val_loss: 0.5430 - val_dice_coef: 0.4777 - val_accuracy: 0.9959 - lr: 3.9063e-06
# Epoch 39/60
# 143/143 [==============================] - 324s 2s/step - loss: 0.5222 - dice_coef: 0.4969 - accuracy: 0.9958 - val_loss: 0.5285 - val_dice_coef: 0.4931 - val_accuracy: 0.9960 - lr: 1.9531e-06
# Epoch 40/60
# 143/143 [==============================] - 323s 2s/step - loss: 0.5173 - dice_coef: 0.5075 - accuracy: 0.9958 - val_loss: 0.5437 - val_dice_coef: 0.4780 - val_accuracy: 0.9960 - lr: 1.9531e-06
# Epoch 41/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5209 - dice_coef: 0.4987 - accuracy: 0.9958 - val_loss: 0.5691 - val_dice_coef: 0.4558 - val_accuracy: 0.9956 - lr: 1.9531e-06
# Epoch 42/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5079 - dice_coef: 0.5107 - accuracy: 0.9959 - val_loss: 0.5361 - val_dice_coef: 0.4866 - val_accuracy: 0.9958 - lr: 1.9531e-06
# Epoch 43/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5262 - dice_coef: 0.4936 - accuracy: 0.9957 - val_loss: 0.5314 - val_dice_coef: 0.4898 - val_accuracy: 0.9960 - lr: 9.7656e-07
# Epoch 44/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5335 - dice_coef: 0.4891 - accuracy: 0.9958 - val_loss: 0.5378 - val_dice_coef: 0.4851 - val_accuracy: 0.9958 - lr: 9.7656e-07
# Epoch 45/60
# 143/143 [==============================] - 321s 2s/step - loss: 0.5110 - dice_coef: 0.5122 - accuracy: 0.9958 - val_loss: 0.5372 - val_dice_coef: 0.4845 - val_accuracy: 0.9959 - lr: 9.7656e-07
# Epoch 46/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5196 - dice_coef: 0.5032 - accuracy: 0.9958 - val_loss: 0.5370 - val_dice_coef: 0.4833 - val_accuracy: 0.9961 - lr: 9.7656e-07
# Epoch 47/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5225 - dice_coef: 0.5020 - accuracy: 0.9958 - val_loss: 0.5260 - val_dice_coef: 0.4964 - val_accuracy: 0.9958 - lr: 4.8828e-07
# Epoch 48/60
# 143/143 [==============================] - 317s 2s/step - loss: 0.5127 - dice_coef: 0.5110 - accuracy: 0.9959 - val_loss: 0.5569 - val_dice_coef: 0.4655 - val_accuracy: 0.9959 - lr: 4.8828e-07
# Epoch 49/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5244 - dice_coef: 0.4988 - accuracy: 0.9958 - val_loss: 0.5441 - val_dice_coef: 0.4761 - val_accuracy: 0.9960 - lr: 4.8828e-07
# Epoch 50/60
# 143/143 [==============================] - 318s 2s/step - loss: 0.5186 - dice_coef: 0.5054 - accuracy: 0.9958 - val_loss: 0.5152 - val_dice_coef: 0.5075 - val_accuracy: 0.9957 - lr: 4.8828e-07
# Epoch 51/60
# 143/143 [==============================] - 319s 2s/step - loss: 0.5259 - dice_coef: 0.4937 - accuracy: 0.9958 - val_loss: 0.5519 - val_dice_coef: 0.4698 - val_accuracy: 0.9959 - lr: 2.4414e-07

# %%
eval_results = model.evaluate(valid_gen, steps=len(data_val) /8, verbose=1)
# Out:
# 35/35 [==============================] - 60s 2s/step - loss: 0.5263 - dice_coef: 0.4944 - accuracy: 0.9959

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(15, 6))

# Plotting the training and validation loss
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_ylabel('Loss')
ax1.legend()

# Plotting the training and validation accuracy
ax2.plot(history.history['dice_coef'], label='Training Accuracy')
ax2.plot(history.history['val_dice_coef'], label='Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.suptitle('Training and Validation Metrics')
plt.show()

# %%
import cv2
for i in range(10):
    index=np.random.randint(1,len(data_test.index))
    img = cv2.imread(data_test['images'].iloc[index])
    img = cv2.resize(img ,(256, 256))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(10,10))
    plt.subplot(1,4,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,4,2)
    plt.imshow(np.squeeze(cv2.imread(data_test['masks'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,4,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.subplot(1,4,4)
    plt.imshow(np.squeeze(img))
    plt.imshow(np.squeeze(pred)>.5,alpha=0.4)
    plt.title('Image with prediction mask')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
model.save('VGG16.h5')
